# %% [markdown]
# ## Gemini aIntegration

# %% [raw]
# ## install Google Gemini package
# !pip install -U google-genai

# %%
## import necessary library
import os
from dotenv import load_dotenv, dotenv_values

# %%
from google import genai

# %%
load_dotenv()

client = genai.Client(
    api_key=os.getenv("gemini_api")
)

# %%
## Create Prompt
prompt = f""" Tell me about SAS in 100 words.   """

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is Agentic AI?"
)

print(response.text)
# Out:
# **Agentic AI** refers to a type of artificial intelligence system designed to act autonomously, pursue specific goals, and make decisions within an environment, often over an extended period and through multiple steps, without requiring constant human intervention.
#
# Think of it as moving beyond a simple chatbot that just responds to prompts, towards an AI that can *take initiative* to achieve a high-level objective.
#
# Here's a breakdown of its key characteristics:
#
# 1.  **Autonomy:** This is the defining feature. Agentic AIs can operate independently, making choices and executing actions based on their understanding of the environment and their goal.
# 2.  **Goal-Oriented:** They are given a high-level objective (e.g., "research the best marketing strategies for a new product," "plan a trip to Paris," "debug this code base") and then work towards achieving it.
# 3.  **Planning and Reasoning:** They can break down complex goals into smaller, manageable sub-tasks, devise a plan of action, and adjust that plan if initial steps fail or new information emerges. This often involves an iterative "observe-plan-act-reflect" loop.
# 4.  **Tool Use:** Agentic AIs are not limited to just processing text. They can integrate and use various external tools and APIs, such as:
#     *   Web browsers (for searching information)
#     *   Code interpreters (to write, test, and execute code)
#     *   Calendar APIs (to schedule events)
#     *   Email clients (to send communications)
#     *   Databases (to store and retrieve information)
#     *   Other AI models (e.g., image generation, summarization)
# 5.  **Environment Interaction:** They can "perceive" their environment (e.g., by reading web pages, interpreting error messages, processing data) and "act" within it (e.g., by clicking buttons, writing code, sending messages, updating files).
# 6.  **Memory and State Management:** They maintain a memory of past actions, observations, and decisions, allowing them to learn from experience and maintain context across multiple steps.
# 7.  **Self-Correction and Adaptability:** If an action fails or leads to an unexpected outcome, an agentic AI can often detect the failure, analyze why it happened, and attempt a different strategy or modify its plan.
#
# **How it Differs from a Standard LLM (e.g., ChatGPT):**
#
# While Large Language Models (LLMs) like GPT-4 are often the "brain" or the "reasoning engine" within an agentic AI system, a standalone LLM is *not* inherently agentic.
#
# *   **LLM:** Primarily a reactive system. It waits for a prompt and generates a response. It doesn't initiate actions, use external tools, or autonomously pursue a multi-step goal unless explicitly programmed to do so *by an external agentic framework*.
# *   **Agentic AI:** A proactive system that *uses* an LLM (or other AI models) as a component. It wraps the LLM with an architecture that enables planning, tool use, memory, and autonomous action to achieve a goal.
#
# **Examples of Agentic AI:**
#
# *   **Auto-GPT, GPT-Engineer, BabyAGI:** Early open-source examples that demonstrated the concept by autonomously planning and executing tasks, often involving coding, web browsing, and file management.
# *   **AI Assistants:** More sophisticated personal assistants that can book appointments, manage your schedule, plan travel, and handle complex queries by interacting with various applications.
# *   **Research Agents:** AIs that can autonomously search the web, synthesize information from multiple sources, generate reports, and even perform basic data analysis.
# *   **Autonomous Software Development:** AI agents that can take a high-level requirement, write code, test it, debug it, and even deploy it without constant human oversight.
#
# In essence, Agentic AI represents a significant step towards more capable and independent AI systems that can not only understand and generate information but also take meaningful action in the real or digital world to achieve defined objectives.
