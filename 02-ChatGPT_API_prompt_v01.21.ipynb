# %% [markdown]
# ## ChatGPT API Prompt

# %% [raw]
# ## install openAI packages
# !pip install openai

# %%
## Import OpenAI library
import os
import openai
from dotenv import load_dotenv, dotenv_values

# %%
## Prepare Prompt
prompt = f""" Tell me about CDISC in 100 words.   """

# %%
## Create Prompt message
message = [{"role" : "user", "content" : prompt}]
print(message)
# Out:
# [{'role': 'user', 'content': ' Tell me about CDISC in 100 words.   '}]

# %%
## Set up ChatGPT API 
#openai.api_key = "xxxxxxx"
load_dotenv()
openai.api_key = os.getenv("chatgpt_api")

# %%
#os.getenv("chatgpt_api")

# %%
## Send Prompt to OpenAI ChatGPT 
response = openai.chat.completions.create(
    model = "gpt-3.5-turbo",
    messages = message,
    temperature =0
    )

# %% [raw]
# ## Print response from OpenAI ChatGPT
# print(response)

# %%
## Print response
print(response.choices[0].message.content)
# Out:
# CDISC, or Clinical Data Interchange Standards Consortium, is a non-profit organization that develops and promotes global data standards for clinical research. These standards help streamline the process of collecting, analyzing, and sharing data in clinical trials, ultimately improving efficiency and data quality. CDISC standards cover a wide range of areas, including data collection, data submission, and data analysis. By using CDISC standards, researchers, pharmaceutical companies, and regulatory agencies can more easily exchange and compare data, leading to faster and more reliable results in the development of new medical treatments.
